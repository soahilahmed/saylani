# %%
import pandas as pd
import numpy as np

# %%
test=pd.read_csv('tested.csv')

# %% [raw]
# Dataset ke pehle 10 rows display karein.

# %%
test.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
# 5          897         0       3
# 6          898         1       3
# 7          899         0       2
# 8          900         1       3
# 9          901         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %% [raw]
# Female passengers jinki age 25 se zyada hai unka data show karein.

# %%
test[(test.Age>=25)&(test.Sex=="female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 6            898         1       3
# 14           906         1       1
# 18           910         1       3
# 19           911         1       3
# ..           ...       ...     ...
# 397         1289         1       1
# 400         1292         1       1
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 6                                 Connolly, Miss. Kate  female  30.0      0
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 18                        Ilmakangas, Miss. Ida Livija  female  27.0      1
# 19               Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Dataset ke last 10 rows display karein.`

# %%
test.tail(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 408         1300         1       3
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 408                  Riordan, Miss. Johanna Hannah""  female   NaN      0
# 409                        Peacock, Miss. Treasteall  female   3.0      1
# 410                           Naughton, Miss. Hannah  female   NaN      0
# 411  Minahan, Mrs. William Edward (Lillian E Thorpe)  female  37.0      1
# 412                   Henriksson, Miss. Jenny Lovisa  female  28.0      0
# 413                               Spector, Mr. Woolf    male   NaN      0
# ...

# %% [raw]
# Male passengers jinki age 40 se kam hai unka data show karein.

# %%
test[(test.Age<=40)&(test.Sex=="male")]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 3            895         0       3
# 5            897         0       3
# 7            899         0       2
# 9            901         0       3
# ..           ...       ...     ...
# 401         1293         0       2
# 403         1295         0       1
# 405         1297         0       2
# 406         1298         0       2
# 415         1307         0       3
#
#                                              Name   Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James  male  34.5      0      0
# 3                                Wirz, Mr. Albert  male  27.0      0      0
# 5                      Svensson, Mr. Johan Cervin  male  14.0      0      0
# 7                    Caldwell, Mr. Albert Francis  male  26.0      1      1
# 9                         Davies, Mr. John Samuel  male  21.0      2      0
# ..                                            ...   ...   ...    ...    ...
# ...

# %% [raw]
# Sirf Name aur Age columns display karein.

# %%
test[["Name",'Age']]
# Out:
#                                              Name   Age
# 0                                Kelly, Mr. James  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0
# 2                       Myles, Mr. Thomas Francis  62.0
# 3                                Wirz, Mr. Albert  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..                                            ...   ...
# 413                            Spector, Mr. Woolf   NaN
# 414                  Oliva y Ocana, Dona. Fermina  39.0
# 415                  Saether, Mr. Simon Sivertsen  38.5
# 416                           Ware, Mr. Frederick   NaN
# 417                      Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]

# %% [raw]
# Sirf female passengers ka data show karein.

# %%
test[test.Sex=="female"]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# ..           ...       ...     ...
# 409         1301         1       3
# 410         1302         1       3
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [raw]
# First Class ke survived passengers show karein.

# %%
test[(test.Pclass==1)&(test.Survived==1)]#[['Pclass','Survived']]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 22           914         1       1
# 24           916         1       1
# 26           918         1       1
# 44           936         1       1
# 48           940         1       1
# 53           945         1       1
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 77           969         1       1
# 92           984         1       1
# 96           988         1       1
# 100          992         1       1
# 112         1004         1       1
# 114         1006         1       1
# 122         1014         1       1
# 141         1033         1       1
# 150         1042         1       1
# 156         1048         1       1
# 168         1060         1       1
# 179         1071         1       1
# 182         1074         1       1
# 184         1076         1       1
# ...

# %% [raw]
# # Third Class ke non-survived passengers show karein.

# %%
test[(test.Pclass==3)&(test.Survived==0)]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 9            901         0       3       Davies, Mr. John Samuel  male  21.0
# 10           902         0       3              Ilieff, Mr. Ylio  male   NaN
# ..           ...       ...     ...                           ...   ...   ...
# 399         1291         0       3      Conlon, Mr. Thomas Henry  male  31.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %% [raw]
# Sirf male passengers ka data show karein.

# %%
test[(test.Sex=="male")]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 2            894         0       2     Myles, Mr. Thomas Francis  male  62.0
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 7            899         0       2  Caldwell, Mr. Albert Francis  male  26.0
# ..           ...       ...     ...                           ...   ...   ...
# 407         1299         0       1    Widener, Mr. George Dunton  male  50.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %% [raw]
# Jin passengers ki age 30 se zyada hai unka data show karein.

# %%
test[(test.Age>=18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 407         1299         0       1
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [raw]
# # Jin passengers ki age 18 se kam hai unka data show karein.

# %%
test[(test.Age<=18)]
# Out:
#      PassengerId  Survived  Pclass  \
# 5            897         0       3
# 8            900         1       3
# 21           913         0       3
# 55           947         0       3
# 60           952         0       3
# 62           954         0       3
# 64           956         0       1
# 66           958         1       3
# 80           972         0       3
# 87           979         1       3
# 89           981         0       2
# 104          996         1       3
# 115         1007         0       3
# 117         1009         1       3
# 120         1012         1       2
# 125         1017         1       3
# 140         1032         1       3
# 154         1046         0       3
# 161         1053         0       3
# 167         1059         0       3
# 175         1067         1       2
# 182         1074         1       1
# 187         1079         0       3
# 192         1084         0       3
# 194         1086         0       2
# ...

# %% [raw]
# Sirf First Class (Pclass = 1) passengers show karein. & Sirf Second Class (Pclass = 2) passengers show karein.

# %%
test[(test.Pclass==1)|(test.Pclass==2) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 2            894         0       2
# 7            899         0       2
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# ..           ...       ...     ...
# 405         1297         0       2
# 406         1298         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 7                       Caldwell, Mr. Albert Francis    male  26.0      1
# 11                        Jones, Mr. Charles Cresson    male  46.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 13                              Howard, Mr. Benjamin    male  63.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [raw]
# Sirf Third Class (Pclass = 3) passengers show karein.

# %%
test[(test.Pclass==3)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %% [raw]
# Sirf survived passengers show karein. &  Sirf non-survived passengers show karein.

# %%
test[(test.Survived==0 )|(test.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [raw]
# Jin passengers ka fare 50 se zyada hai unka data show karein. & Jin passengers ka fare 20 se kam hai unka data show karein.

# %%
test[(test.Fare>50)|(test.Fare<20)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [raw]
# Jinki Embarked value 'S' hai unka data show karein

# %%
test[(test.Embarked=='S')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 7            899         0       2
# ..           ...       ...     ...
# 409         1301         1       3
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# 7                    Caldwell, Mr. Albert Francis    male  26.0      1      1
# ...

# %% [raw]
# 1 - Age 20 aur 40 ke darmiyan wale passengers show karein.
# 2 - Fare 20 aur 80 ke darmiyan wale passengers show karein.

# %%
test[(test.Age>=20)&(test.Age<=40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 3            895         0       3
# 4            896         1       3
# 6            898         1       3
# 7            899         0       2
# ..           ...       ...     ...
# 406         1298         0       2
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 7                       Caldwell, Mr. Albert Francis    male  26.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
test[(test.Fare>=20)&(test.Fare<=80)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7            899         0       2
# 9            901         0       3
# 11           903         0       1
# 13           905         0       2
# 14           906         1       1
# ..           ...       ...     ...
# 401         1293         0       2
# 402         1294         1       1
# 403         1295         0       1
# 404         1296         0       1
# 417         1309         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 7                         Caldwell, Mr. Albert Francis    male  26.0      1
# 9                              Davies, Mr. John Samuel    male  21.0      2
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# 1 - Female passengers jo First Class me travel kar rahi thin.
# 2 - Male passengers jo Third Class me travel kar rahe the.

# %%
test[(test.Sex=='female')&(test.Pclass==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 22           914         1       1
# 24           916         1       1
# 26           918         1       1
# 44           936         1       1
# 48           940         1       1
# 53           945         1       1
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 77           969         1       1
# 92           984         1       1
# 96           988         1       1
# 100          992         1       1
# 112         1004         1       1
# 114         1006         1       1
# 122         1014         1       1
# 141         1033         1       1
# 150         1042         1       1
# 156         1048         1       1
# 168         1060         1       1
# 179         1071         1       1
# 182         1074         1       1
# 184         1076         1       1
# ...

# %%
test[(test.Sex=='male')&(test.Pclass==3)]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0            892         0       3              Kelly, Mr. James  male  34.5
# 3            895         0       3              Wirz, Mr. Albert  male  27.0
# 5            897         0       3    Svensson, Mr. Johan Cervin  male  14.0
# 9            901         0       3       Davies, Mr. John Samuel  male  21.0
# 10           902         0       3              Ilieff, Mr. Ylio  male   NaN
# ..           ...       ...     ...                           ...   ...   ...
# 399         1291         0       3      Conlon, Mr. Thomas Henry  male  31.0
# 413         1305         0       3            Spector, Mr. Woolf  male   NaN
# 415         1307         0       3  Saether, Mr. Simon Sivertsen  male  38.5
# 416         1308         0       3           Ware, Mr. Frederick  male   NaN
# 417         1309         0       3      Peter, Master. Michael J  male   NaN
#
# ...

# %% [raw]
# Embarked = 'C' wale passengers show karein.
# Embarked = 'Q' wale passengers show karein.

# %%
test[(test.Embarked=='C')]
# Out:
#      PassengerId  Survived  Pclass  \
# 8            900         1       3
# 15           907         1       2
# 17           909         0       3
# 19           911         1       3
# 20           912         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 414         1306         1       1
# 417         1309         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 8        Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 15   del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# 17                               Assaf, Mr. Gerios    male  21.0      0
# 19           Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
# 20                          Rothschild, Mr. Martin    male  55.0      1
# ..                                             ...     ...   ...    ...
# ...

# %%
test[(test.Embarked=='Q')]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 2            894         0       2
# 6            898         1       3
# 16           908         0       2
# 47           939         0       3
# 55           947         0       3
# 63           955         1       3
# 66           958         1       3
# 70           962         1       3
# 79           971         1       3
# 84           976         0       2
# 86           978         1       3
# 88           980         1       3
# 102          994         0       3
# 106          998         0       3
# 107          999         0       3
# 111         1003         1       3
# 113         1005         1       3
# 121         1013         0       3
# 124         1016         0       3
# 127         1019         1       3
# 160         1052         1       3
# 183         1075         0       3
# 193         1085         0       2
# 200         1092         1       3
# ...

# %% [raw]
# Embarked = 'Q' wale passengers show karein.

# %%
test[(test.Embarked=='Q')]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 2            894         0       2
# 6            898         1       3
# 16           908         0       2
# 47           939         0       3
# 55           947         0       3
# 63           955         1       3
# 66           958         1       3
# 70           962         1       3
# 79           971         1       3
# 84           976         0       2
# 86           978         1       3
# 88           980         1       3
# 102          994         0       3
# 106          998         0       3
# 107          999         0       3
# 111         1003         1       3
# 113         1005         1       3
# 121         1013         0       3
# 124         1016         0       3
# 127         1019         1       3
# 160         1052         1       3
# 183         1075         0       3
# 193         1085         0       2
# 200         1092         1       3
# ...

# %% [raw]
# Fare 100 se zyada aur survived passengers show karein.

# %%
test[(test.Fare>=100)&(test.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 24           916         1       1
# 53           945         1       1
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 114         1006         1       1
# 141         1033         1       1
# 156         1048         1       1
# 184         1076         1       1
# 218         1110         1       1
# 239         1131         1       1
# 272         1164         1       1
# 314         1206         1       1
# 324         1216         1       1
# 343         1235         1       1
# 371         1263         1       1
# 375         1267         1       1
# 400         1292         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# ...

# %% [raw]
# Dataset ko Age ke hisaab se ascending order me sort karein.

# %%
test.sort_values(by="Age",ascending=True)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 354         1246         1       3  Dean, Miss. Elizabeth Gladys Millvina""
# 201         1093         0       3  Danbom, Master. Gilbert Sigvard Emanuel
# 281         1173         0       3           Peacock, Master. Alfred Edward
# 307         1199         0       3                Aks, Master. Philip Frank
# 250         1142         1       2                    West, Miss. Barbara J
# ..           ...       ...     ...                                      ...
# 408         1300         1       3          Riordan, Miss. Johanna Hannah""
# 410         1302         1       3                   Naughton, Miss. Hannah
# 413         1305         0       3                       Spector, Mr. Woolf
# 416         1308         0       3                      Ware, Mr. Frederick
# 417         1309         0       3                 Peter, Master. Michael J
#
# ...

# %% [raw]
# Dataset ko Fare ke hisaab se descending order me sort karein.

# %%
test.sort_values(by="Fare",ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 53           945         1       1
# 69           961         1       1
# 24           916         1       1
# 142         1034         0       1
# ..           ...       ...     ...
# 133         1025         0       3
# 21           913         0       3
# 266         1158         0       1
# 372         1264         0       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 142                         Ryerson, Mr. Arthur Larned    male  61.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Jinki Cabin value missing hai unka data show karein.

# %%
test[(test.Cabin.isna())]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [raw]
# Sirf woh passengers show karein jinke paas Cabin available hai.

# %%
test[(test.Cabin.notnull())]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Female passengers jinki age 18 se 35 ke darmiyan ho aur survive bhi kiya ho.

# %%
test[(test.Sex=="female")&(test.Age>=18)&(test.Age<=35) & (test.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# 15           907         1       2
# ..           ...       ...     ...
# 385         1277         1       2
# 395         1287         1       1
# 400         1292         1       1
# 402         1294         1       1
# 412         1304         1       3
#
#                                                Name     Sex   Age  SibSp  \
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                              Connolly, Miss. Kate  female  30.0      0
# 8         Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12    Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 15    del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# ..                                              ...     ...   ...    ...
# ...

# %% [raw]
# Female passengers jinki age 18 se 35 ke darmiyan ho aur survive bhi kiya ho.

# %%
test[(test.Sex=="female")&(test.Age>=18)&(test.Age<=35) & (test.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 6            898         1       3
# 8            900         1       3
# 12           904         1       1
# 15           907         1       2
# ..           ...       ...     ...
# 385         1277         1       2
# 395         1287         1       1
# 400         1292         1       1
# 402         1294         1       1
# 412         1304         1       3
#
#                                                Name     Sex   Age  SibSp  \
# 4      Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                              Connolly, Miss. Kate  female  30.0      0
# 8         Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12    Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 15    del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# ..                                              ...     ...   ...    ...
# ...

# %% [raw]
# First Class ke passengers jinki age 50 se zyada hai.

# %%
test[(test.Pclass==1)&(test.Age>=50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 20           912         0       1
# 48           940         1       1
# 69           961         1       1
# 77           969         1       1
# 81           973         0       1
# 96           988         1       1
# 114         1006         1       1
# 131         1023         0       1
# 142         1034         0       1
# 177         1069         0       1
# 179         1071         1       1
# 217         1109         0       1
# 218         1110         1       1
# 224         1116         1       1
# 236         1128         0       1
# 240         1132         1       1
# 293         1185         0       1
# 305         1197         1       1
# 308         1200         0       1
# 314         1206         1       1
# 316         1208         0       1
# 343         1235         1       1
# 355         1247         0       1
# 356         1248         1       1
# 374         1266         1       1
# ...

# %% [raw]
# Third Class ke passengers jinka fare 10 se kam hai.

# %%
test[(test.Pclass==3)&(test.Fare<=10)]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 0            892         0       3                  Kelly, Mr. James    male
# 1            893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 3            895         0       3                  Wirz, Mr. Albert    male
# 5            897         0       3        Svensson, Mr. Johan Cervin    male
# 6            898         1       3              Connolly, Miss. Kate  female
# ..           ...       ...     ...                               ...     ...
# 410         1302         1       3            Naughton, Miss. Hannah  female
# 412         1304         1       3    Henriksson, Miss. Jenny Lovisa  female
# 413         1305         0       3                Spector, Mr. Woolf    male
# 415         1307         0       3      Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3               Ware, Mr. Frederick    male
#
# ...

# %% [raw]
# Jin passengers ke naam me "Mr." likha hua hai unka data show karein.

# %%
test[(test.Name.str.contains('Mr'))]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 407         1299         0       1
# 411         1303         1       1
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [raw]
# 1 -Jin passengers ke naam me "Mrs." likha hua hai unka data show karein.
# 2 - Jin passengers ke naam me "Miss." likha hua hai unka data show karein.

# %%
test[(test.Name.str.contains('Mrs'))]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 4            896         1       3
# 8            900         1       3
# 12           904         1       1
# 14           906         1       1
# ..           ...       ...     ...
# 383         1275         1       3
# 391         1283         1       1
# 395         1287         1       1
# 397         1289         1       1
# 411         1303         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4         Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
test[(test.Name.str.contains('Miss'))]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 6            898         1       3             Connolly, Miss. Kate  female
# 18           910         1       3     Ilmakangas, Miss. Ida Livija  female
# 26           918         1       1     Ostby, Miss. Helene Ragnhild  female
# 36           928         1       3              Roth, Miss. Sarah A  female
# 37           929         1       3               Cacic, Miss. Manda  female
# ..           ...       ...     ...                              ...     ...
# 402         1294         1       1   Gibson, Miss. Dorothy Winifred  female
# 408         1300         1       3  Riordan, Miss. Johanna Hannah""  female
# 409         1301         1       3        Peacock, Miss. Treasteall  female
# 410         1302         1       3           Naughton, Miss. Hannah  female
# 412         1304         1       3   Henriksson, Miss. Jenny Lovisa  female
#
# ...

# %% [raw]
# Age missing hone wale passengers show karein.

# %%
test[(test.Age.isna())]
# Out:
#      PassengerId  Survived  Pclass  \
# 10           902         0       3
# 22           914         1       1
# 29           921         0       3
# 33           925         1       3
# 36           928         1       3
# ..           ...       ...     ...
# 408         1300         1       3
# 410         1302         1       3
# 413         1305         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 10                                    Ilieff, Mr. Ylio    male  NaN      0
# 22                Flegenheim, Mrs. Alfred (Antoinette)  female  NaN      0
# 29                                   Samaan, Mr. Elias    male  NaN      2
# 33   Johnston, Mrs. Andrew G (Elizabeth Lily" Watson)"  female  NaN      1
# 36                                 Roth, Miss. Sarah A  female  NaN      0
# ..                                                 ...     ...  ...    ...
# ...

# %% [raw]
# Fare dataset ke average fare se zyada rakhne wale passengers show karein.

# %%
# test.Fare.mean()
test[(test.Fare>= test.Fare.mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 23           915         0       1
# 24           916         1       1
# ..           ...       ...     ...
# 402         1294         1       1
# 403         1295         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 23                     Williams, Mr. Richard Norris II    male  21.0      0
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
#  Age dataset ki average age se zyada rakhne wale passengers show karein.

# %%
test.Age.mean()
test[(test.Age>test.Age.mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 11           903         0       1
# 13           905         0       2
# ..           ...       ...     ...
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 11                        Jones, Mr. Charles Cresson    male  46.0      0
# 13                              Howard, Mr. Benjamin    male  63.0      1
# ..                                               ...     ...   ...    ...
# ...

# %% [raw]
# Survived passengers ko Fare ke descending order me display karein.

# %%
test[(test.Survived==1)].sort_values(by="Fare",ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 343         1235         1       1
# 53           945         1       1
# 69           961         1       1
# 59           951         1       1
# 375         1267         1       1
# ..           ...       ...     ...
# 8            900         1       3
# 347         1239         1       3
# 19           911         1       3
# 1            893         1       3
# 291         1183         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 343  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58.0      0
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 69                 Fortune, Mrs. Mark (Mary McDougald)  female  60.0      1
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# 375                           Bowen, Miss. Grace Scott  female  45.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Third Class ki female passengers jinki age 25 se kam ho aur survive kiya ho.

# %%
test[(test.Pclass==3)&(test.Sex=="female")&(test.Age<=25)&(test.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 4            896         1       3
# 8            900         1       3
# 37           929         1       3
# 63           955         1       3
# 66           958         1       3
# 70           962         1       3
# 79           971         1       3
# 87           979         1       3
# 90           982         1       3
# 98           990         1       3
# 104          996         1       3
# 113         1005         1       3
# 117         1009         1       3
# 125         1017         1       3
# 138         1030         1       3
# 140         1032         1       3
# 157         1049         1       3
# 169         1061         1       3
# 197         1089         1       3
# 263         1155         1       3
# 280         1172         1       3
# 283         1175         1       3
# 284         1176         1       3
# 315         1207         1       3
# 333         1225         1       3
# ...

# %% [raw]
# First Class ke passengers jinka Fare 100 se zyada aur Age 30 se zyada ho.

# %%
test[(test.Pclass==1)&(test.Fare>=100)&(test.Age>=30)]
# Out:
#      PassengerId  Survived  Pclass  \
# 24           916         1       1
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 75           967         0       1
# 81           973         0       1
# 114         1006         1       1
# 141         1033         1       1
# 142         1034         0       1
# 202         1094         0       1
# 217         1109         0       1
# 218         1110         1       1
# 239         1131         1       1
# 242         1134         0       1
# 306         1198         0       1
# 314         1206         1       1
# 316         1208         0       1
# 324         1216         1       1
# 343         1235         1       1
# 371         1263         1       1
# 375         1267         1       1
# 400         1292         1       1
# 407         1299         0       1
# 414         1306         1       1
#
# ...

# %% [raw]
# Aise passengers show karein jo Embarked 'S', Fare > 50, aur Female hon.

# %%
test[(test.Embarked=='S')&(test.Fare>=50)&(test.Sex=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 44           936         1       1
# 53           945         1       1
# 69           961         1       1
# 92           984         1       1
# 96           988         1       1
# 114         1006         1       1
# 141         1033         1       1
# 156         1048         1       1
# 182         1074         1       1
# 188         1080         1       3
# 324         1216         1       1
# 356         1248         1       1
# 365         1257         1       3
# 374         1266         1       1
# 385         1277         1       2
# 395         1287         1       1
# 400         1292         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ...

# %% [raw]
# Aise passengers show karein jo Second ya Third Class me hon aur unki age 15 se 30 ke darmiyan

# %%
test[((test.Pclass==2 )| (test.Pclass==3 )) & ((test.Age>=15)&(test.Age<=30))]
# Out:
#      PassengerId  Survived  Pclass  \
# 3            895         0       3
# 4            896         1       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# ..           ...       ...     ...
# 396         1288         0       3
# 398         1290         0       3
# 405         1297         0       2
# 406         1298         0       2
# 412         1304         1       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 6                            Connolly, Miss. Kate  female  30.0      0      0
# 7                    Caldwell, Mr. Albert Francis    male  26.0      1      1
# 8       Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0      0
# ...

# %% [raw]
# Un female passengers ka data show karein jo First Class me travel kar rahi thin, Age > 25, Fare > 100, aur Survived = 1 ho.

# %%
test[(test.Sex=="female")&(test.Pclass==1)&(test.Age>25)&(test.Fare>100)&(test.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 24           916         1       1
# 53           945         1       1
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 114         1006         1       1
# 141         1033         1       1
# 156         1048         1       1
# 184         1076         1       1
# 218         1110         1       1
# 239         1131         1       1
# 272         1164         1       1
# 314         1206         1       1
# 324         1216         1       1
# 343         1235         1       1
# 371         1263         1       1
# 375         1267         1       1
# 400         1292         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# ...

# %% [raw]
# Un male passengers ka data show karein jo Third Class me travel kar rahe the, Age 18 se 40 ke darmiyan ho, aur Fare < 20 ho.

# %%
test[(test.Sex=="male")&(test.Pclass==3)&(test.Age>18)&(test.Age<40)&(test.Fare<20)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 3            895         0       3
# 17           909         0       3
# 27           919         0       3
# 35           927         0       3
# ..           ...       ...     ...
# 388         1280         0       3
# 396         1288         0       3
# 398         1290         0       3
# 399         1291         0       3
# 415         1307         0       3
#
#                                                  Name   Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James  male  34.5      0
# 3                                    Wirz, Mr. Albert  male  27.0      0
# 17                                  Assaf, Mr. Gerios  male  21.0      0
# 27                                  Daher, Mr. Shedid  male  22.5      0
# 35   Katavelas, Mr. Vassilios (Catavelas Vassilios")"  male  18.5      0
# ..                                                ...   ...   ...    ...
# ...

# %% [raw]
#  Aise passengers ka data show karein jinke Name me "Mr." ya "Mrs." ho aur unka Fare dataset ke average fare se zyada ho.

# %%
test[((test.Name.str.contains("Mr"))|(test.Name.str.contains("Mrs")))  & (test.Fare>test.Fare.mean()) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 20           912         0       1
# 23           915         0       1
# 24           916         1       1
# ..           ...       ...     ...
# 395         1287         1       1
# 397         1289         1       1
# 403         1295         0       1
# 407         1299         0       1
# 411         1303         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 23                     Williams, Mr. Richard Norris II    male  21.0      0
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
#  Aise passengers show karein jinki Age missing nahi hai, Cabin bhi available hai, aur Fare 50 se zyada hai.

# %%
test[(test.Age.notnull()) &(test.Cabin.notnull())&(test.Fare>50)]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 34           926         0       1
# 44           936         1       1
# 48           940         1       1
# 50           942         0       1
# 53           945         1       1
# 59           951         1       1
# 64           956         0       1
# 69           961         1       1
# 74           966         1       1
# 75           967         0       1
# 81           973         0       1
# 92           984         1       1
# 96           988         1       1
# 100          992         1       1
# 114         1006         1       1
# 118         1010         0       1
# 122         1014         1       1
# 142         1034         0       1
# 150         1042         1       1
# 156         1048         1       1
# 166         1058         0       1
# ...

# %% [raw]
# Sirf un passengers ka data show karein jinka Embarked 'S' ya 'C' ho, Age > 30, aur Survived = 1 ho.

# %%
test[((test.Embarked=='S')|(test.Embarked=='C')) &(test.Age>30)&(test.Survived==1) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 14           906         1       1
# 19           911         1       3
# 24           916         1       1
# 32           924         1       3
# 44           936         1       1
# 48           940         1       1
# 49           941         1       3
# 59           951         1       1
# 69           961         1       1
# 74           966         1       1
# 77           969         1       1
# 96           988         1       1
# 100          992         1       1
# 112         1004         1       1
# 114         1006         1       1
# 122         1014         1       1
# 141         1033         1       1
# 153         1045         1       3
# 178         1070         1       2
# 179         1071         1       1
# 208         1100         1       1
# 213         1105         1       2
# 214         1106         1       3
# 218         1110         1       1
# ...

# %% [raw]
# # Dataset me se un passengers ka data show karein jinki Age dataset ki average age se kam ho aur Fare dataset ke average fare se zyada ho.

# %%
test[(test.Age<test.Age.mean()) & (test.Fare>test.Fare.mean())]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 23           915         0       1
# 26           918         1       1
# 34           926         0       1
# 50           942         0       1
# 53           945         1       1
# 64           956         0       1
# 92           984         1       1
# 140         1032         1       3
# 150         1042         1       1
# 156         1048         1       1
# 175         1067         1       2
# 176         1068         1       2
# 182         1074         1       1
# 184         1076         1       1
# 196         1088         0       1
# 212         1104         0       2
# 230         1122         0       2
# 252         1144         0       1
# 272         1164         1       1
# 287         1179         0       1
# 296         1188         1       2
# 298         1190         0       1
# 306         1198         0       1
# 326         1218         1       2
# ...

# %% [raw]
# # Un passengers ka data show karein jinka Name "Miss." se contain karta ho, Age < 25, Pclass = 1, aur Survived = 1 ho. Output ko Fare ke descending order me display karein.

# %%
test[(test.Name.str.contains('Miss')) &(test.Age<25)&(test.Pclass==1)&(test.Survived==1)].sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 26           918         1       1    Ostby, Miss. Helene Ragnhild  female
# 402         1294         1       1  Gibson, Miss. Dorothy Winifred  female
# 231         1123         1       1        Willard, Miss. Constance  female
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 26   22.0      0      1  113509  61.9792   B36        C
# 402  22.0      0      1  112378  59.4000   NaN        C
# 231  21.0      0      0  113795  26.5500   NaN        S

# %% [raw]
# Un passengers ka data show karein jinka Fare top 10 highest fares me aata ho aur output ko Age ke ascending order me sort karein.

# %%
test.sort_values(by="Fare",ascending=False).head(10).sort_values(by="Age",ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 64           956         0       1
# 184         1076         1       1
# 53           945         1       1
# 59           951         1       1
# 375         1267         1       1
# 202         1094         0       1
# 24           916         1       1
# 343         1235         1       1
# 69           961         1       1
# 142         1034         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 64                         Ryerson, Master. John Borie    male  13.0      2
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...  female  27.0      1
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# 375                           Bowen, Miss. Grace Scott  female  45.0      0
# 202                             Astor, Col. John Jacob    male  47.0      1
# ...

# %% [raw]
# Aise passengers show karein jinki Age 20–50 ke darmiyan ho, Embarked 'Q' na ho, aur Fare 30–100 ke darmiyan ho.

# %%
test[((test.Age>20)&(test.Age<50)) & (test.Embarked!='Q') &((test.Fare>30)&(test.Fare<300)) ]
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 23           915         0       1
# 24           916         1       1
# 26           918         1       1
# ..           ...       ...     ...
# 390         1282         0       1
# 397         1289         1       1
# 400         1292         1       1
# 402         1294         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 23                     Williams, Mr. Richard Norris II    male  21.0      0
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Ek hi query me un passengers ka data show karein jo:
# - Female hon
# - First ya Second Class me travel kar rahi hon
# - Age > 18
# - Fare > dataset ke average fare
# - Survived = 1
# - Output ko Fare (Descending) aur phir Age (Ascending) ke hisaab se sort karein.

# %%
test[( test.Sex=='female')& ((test.Pclass==1)|(test.Pclass==2)) & (test.Age>18) & (test.Fare>test.Fare.mean()) & (test.Survived==1)].sort_values(by="Fare",ascending=False).sort_values(by="Age",ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 176         1068         1       2
# 402         1294         1       1
# 26           918         1       1
# 12           904         1       1
# 150         1042         1       1
# 361         1253         1       2
# 385         1277         1       2
# 364         1256         1       1
# 272         1164         1       1
# 184         1076         1       1
# 92           984         1       1
# 53           945         1       1
# 156         1048         1       1
# 400         1292         1       1
# 371         1263         1       1
# 141         1033         1       1
# 74           966         1       1
# 122         1014         1       1
# 59           951         1       1
# 178         1070         1       2
# 411         1303         1       1
# 414         1306         1       1
# 324         1216         1       1
# 100          992         1       1
# 368         1260         1       1
# ...

# %% [raw]
# Ek hi query me un passengers ka data show karein jo:
#
#  - Male hon
#  - Third Class me travel kar rahe hon
#  - Age 18 se 45 ke darmiyan ho
#  - Fare dataset ke average fare se kam ho
#  - Survived = 0
#  - Output ko Age (Ascending) aur phir Fare (Descending) ke hisaab se sort karein.

# %%
test[( test.Sex=='male')& (test.Pclass==3) & ((test.Age>18)&(test.Age<45)) & (test.Fare<test.Fare.mean()) & (test.Survived==0)].sort_values(by="Age",ascending=True).sort_values(by="Fare",ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 174         1066         0       3
# 9            901         0       3
# 210         1102         0       3
# 105          997         0       3
# 394         1286         0       3
# ..           ...       ...     ...
# 171         1063         0       3
# 136         1028         0       3
# 237         1129         0       3
# 325         1217         0       3
# 232         1124         0       3
#
#                                            Name   Sex   Age  SibSp  Parch  \
# 174  Asplund, Mr. Carl Oscar Vilhelm Gustafsson  male  40.0      1      5
# 9                       Davies, Mr. John Samuel  male  21.0      2      0
# 210                 Andersen, Mr. Albert Karvin  male  32.0      0      0
# 105                   Holthen, Mr. Johan Martin  male  28.0      0      0
# 394                    Kink-Heilmann, Mr. Anton  male  29.0      3      1
# ..                                          ...   ...   ...    ...    ...
# ...

# %% [raw]
# Female hon
# - Age 20 se 40 ke darmiyan ho
# - Embarked 'S' ya 'C' ho
# - Fare 50 se zyada ho
# - Cabin available ho (missing na ho)
# - Output ko Fare (Descending) ke hisaab se sort karein.

# %%
test[(test.Sex=='female')& ((test.Age>20)&(test.Age<40))& ((test.Embarked=='S')|(test.Embarked=='C')) & (test.Fare>50)& (test.Cabin.notnull())].sort_values(by="Fare",ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 53           945         1       1
# 59           951         1       1
# 184         1076         1       1
# 156         1048         1       1
# 74           966         1       1
# 400         1292         1       1
# 272         1164         1       1
# 371         1263         1       1
# 414         1306         1       1
# 150         1042         1       1
# 12           904         1       1
# 26           918         1       1
# 122         1014         1       1
# 364         1256         1       1
# 92           984         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 53                          Fortune, Miss. Ethel Flora  female  28.0      3
# 59                         Chaudanson, Miss. Victorine  female  36.0      0
# 184  Douglas, Mrs. Frederick Charles (Mary Helene B...  female  27.0      1
# 156                                  Bird, Miss. Ellen  female  29.0      0
# ...

# %% [raw]
# Ek hi query me un passengers ka data show karein jo:
#
#  - First ya Third Class me travel kar rahe hon
#  - Age dataset ki average age se zyada ho
#  - Fare dataset ke average fare se zyada ho
#  - Name me "Mr." likha ho
#  - Output ko Age (Descending) aur phir Fare (Ascending) ke hisaab se sort karein.

# %%
test[(( test.Pclass==1)|( test.Pclass==3)) & (test.Age>test.Age.mean())& (test.Name.str.contains("Mr"))].sort_values(by="Age",ascending=False).sort_values(by="Fare",ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 372         1264         0       1
# 1            893         1       3
# 19           911         1       3
# 347         1239         1       3
# 337         1229         0       3
# ..           ...       ...     ...
# 24           916         1       1
# 142         1034         0       1
# 69           961         1       1
# 343         1235         1       1
# 152         1044         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 372                            Ismay, Mr. Joseph Bruce    male  49.0      0
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 19               Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0      0
# 347    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)  female  38.0      0
# 337                                  Elias, Mr. Joseph    male  39.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Ek hi query me un passengers ka data show karein jo:
#
# - Female hon
# - Name me "Miss." ya "Mrs." likha ho
# - Age 15 se 35 ke darmiyan ho
# - Survived = 1
# - Embarked 'Q' na ho
# - Output ko Name (Ascending) ke hisaab se sort karein.

# %%
test[(test.Sex=='female')&((test.Name.str.contains('Miss'))| (test.Name.str.contains('Mrs')) ) & ((test.Age>15)&(test.Age<35)) &( test.Survived==1) & (test.Embarked!='Q')].sort_values(by="Name",ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 345         1237         1       3
# 8            900         1       3
# 87           979         1       3
# 258         1150         1       2
# 156         1048         1       1
# ..           ...       ...     ...
# 262         1154         1       2
# 231         1123         1       1
# 371         1263         1       1
# 162         1054         1       2
# 15           907         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 345                        Abelseth, Miss. Karen Marie  female  16.0      0
# 8            Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 87                          Badman, Miss. Emily Louisa  female  18.0      0
# 258                            Bentham, Miss. Lilian W  female  19.0      0
# 156                                  Bird, Miss. Ellen  female  29.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [raw]
# Ek hi query me un passengers ka data show karein jo:
#
# - Second Class me travel kar rahe hon
# - Age missing na ho
# - Fare 25 se 100 ke darmiyan ho
# - Embarked 'C' ya 'S' ho
# - Survived = 1
# - Output ko pehle Fare (Descending) aur phir Age (Ascending) ke hisaab se sort karein.

# %%
test[(test.Pclass==2)& (test.Age.notnull())&((test.Fare>25)&(test.Fare<100)) & ((test.Embarked=='C')|(test.Embarked=='S')) & (test.Survived==1)].sort_values(by='Fare',ascending=False).sort_values(by='Age',ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 250         1142         1       2
# 296         1188         1       2
# 203         1095         1       2
# 326         1218         1       2
# 175         1067         1       2
# 176         1068         1       2
# 275         1167         1       2
# 385         1277         1       2
# 361         1253         1       2
# 15           907         1       2
# 119         1011         1       2
# 248         1140         1       2
# 178         1070         1       2
# 241         1133         1       2
# 330         1222         1       2
# 213         1105         1       2
#
#                                                   Name     Sex    Age  SibSp  \
# 250                              West, Miss. Barbara J  female   0.92      1
# 296                              Laroche, Miss. Louise  female   1.00      1
# 203                         Quick, Miss. Winifred Vera  female   8.00      1
# ...
